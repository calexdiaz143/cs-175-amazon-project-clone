# %% [markdown]
# # Load data and classifiers

# %%
from main import *
import eli5
LOAD_SAVED = True
OVERWRITE_SAVED = False
train_X, train_Y, test_X, test_Y, summary_cv, review_cv = memo.get_data(LOAD_SAVED, OVERWRITE_SAVED, CATEGORIES, 0.75, 1000)
clf_nb = memo.get_classifier(LOAD_SAVED, OVERWRITE_SAVED, trainer.naive_bayes, train_X, train_Y, 'clf_nb')
clf_lr = memo.get_classifier(LOAD_SAVED, OVERWRITE_SAVED, trainer.logistic_regression, train_X, train_Y, 'clf_lr')
clf_svm = memo.get_classifier(LOAD_SAVED, OVERWRITE_SAVED, trainer.svm, train_X, train_Y, 'clf_svm')
summary_cv = memo.load_pkl('static/summary_cv')
review_cv = memo.load_pkl('static/review_cv')
classes = list(sorted(set(train_Y)))

# %% [markdown]
# # Visualizing the classifiers

# %% [markdown]
# ## Weight skews (Logistic Regression)

# %%
feature_names = summary_cv.get_feature_names() + review_cv.get_feature_names() + ['helpfulness rating'] + ['overall rating'] + ['review time']

# %%
eli5.show_weights(clf_lr,top=5,feature_names=feature_names,targets=classes)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Amazon_Instant_Video
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Apps_for_Android
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Automotive
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Baby
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Beauty
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Books
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=CDs_and_Vinyl
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Cell_Phones_and_Accessories
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Clothing_Shoes_and_Jewelry
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Digital_Music
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Electronics
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Grocery_and_Gourmet_Food
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Health_and_Personal_Care
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Home_and_Kitchen
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Kindle_Store
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Movies_and_TV
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Musical_Instruments
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Office_Products
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Patio_Lawn_and_Garden
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Pet_Supplies
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Sports_and_Outdoors
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Tools_and_Home_Improvement
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Toys_and_Games
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Video_Games
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.44%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +16.198
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         mitchum
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.59%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +15.968
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         seasons
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.87%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +15.563
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ncis
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.77%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +14.253
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         1970s
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.91%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-alig

# %% [markdown]
# ## Example Prediction

# %%
eli5.show_prediction(clf_lr, test_X.getrow(400), feature_names=feature_names, targets=classes)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Amazon_Instant_Video
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-28.078</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Apps_for_Android
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-34.114</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Automotive
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-32.519</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Baby
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-30.610</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Beauty
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-32.857</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Books
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-26.783</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=CDs_and_Vinyl
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-20.331</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Cell_Phones_and_Accessories
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-33.304</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Clothing_Shoes_and_Jewelry
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-27.694</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Digital_Music
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-16.382</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Electronics
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-17.825</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Grocery_and_Gourmet_Food
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-26.808</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Health_and_Personal_Care
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-16.616</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Home_and_Kitchen
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-15.600</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Kindle_Store
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-22.777</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Movies_and_TV
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-39.303</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Musical_Instruments
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-16.115</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Office_Products
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-21.853</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Patio_Lawn_and_Garden
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-9.900</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Pet_Supplies
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-25.164</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Sports_and_Outdoors
#
# </b>
#
#
#     (probability <b>0.002</b>, score <b>-6.360</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Tools_and_Home_Improvement
#
# </b>
#
#
#     (probability <b>0.998</b>, score <b>2.197</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Toys_and_Games
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-22.079</b>)
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Video_Games
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-25.507</b>)
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 <

# %% [markdown]
# Some notes about our features:
# - Features like review time, helpfulness rating, and overall rating seemed to have negative contributions to almost all category predictions.
# - Our bias was always a strong feature, however almost always negative.
# - Because we had two separate BOWs for our summary and review text, some words show up twice in the prediction models above.

# %% [markdown]
# # Predict

# %% [markdown]
# ## Naive Bayes

# %%
test_prd_nb = clf_nb.predict(test_X)
test_err_nb = tester.error_ratio(test_Y, test_prd_nb)

tester.disp_conf_matrix(test_Y, test_prd_nb, classes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-86f0c27b841f> in <module>()
#       2 test_err_nb = tester.error_ratio(test_Y, test_prd_nb)
#       3
# ----> 4 tester.disp_conf_matrix(test_Y, test_prd_nb, classes)
#
# ~/Documents/ProgrammingProjects/cs175-amazon-project/main/tester.py in disp_conf_matrix(Y, Y_hat, classes)
#      25 def disp_conf_matrix(Y, Y_hat, classes):
#      26     cm = confusion_matrix(Y, Y_hat,labels=classes)
# ---> 27     cm = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
#      28     plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
#      29     plt.title('Confusion matrix')
#
# NameError: name 'np' is not defined

# %% [markdown]
# ## Logistic Regression

# %%
test_prd_lr = clf_lr.predict(test_X)
test_err_lr = tester.error_ratio(test_Y, test_prd_lr)

# %% [markdown]
# ## Ensemble

# %%
test_predictions = [test_prd_nb, test_prd_lr]
test_prd_ensemble = tester.predict_ensemble(test_X, test_predictions)
test_err_ensemble = tester.error_ratio(test_Y, test_prd_ensemble)

# %% [markdown]
# # Results

# %%
print("Naive Bayes Testing Error:         ",test_err_nb)
print("Logistic Regression Testing Error: ",test_err_lr)
print("Ensemble Testing Error:            ",test_err_ensemble)
# Out:
# Naive Bayes Testing Error:          0.24665461121157323
# Logistic Regression Testing Error:  0.17902350813743217
# Ensemble Testing Error:             0.24665461121157323
